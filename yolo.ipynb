# %%
from ultralytics import YOLO
import cv2
import numpy as np
from scipy.spatial.distance import cdist
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
broadcast_video = 'broadcast.mp4'
tacticam_video = 'tacticam.mp4'
model_path = 'best.pt'
confidence_threshold = 0.4

# %%
model = YOLO(model_path)

# %%
def detect_players(frame):
    result = model(frame)
    detections = []
    for r in result[0].boxes:
        if r.conf > confidence_threshold and r.cls == 2:
            x1, y1, x2, y2 = map(int, r.xyxy[0].tolist())
            detections.append({'bbox': (x1, y1, x2, y2), 'confidence': float(r.conf)})
    return detections

# %%
def extract_appearance_feature(frame, bbox):
    x1, y1, x2, y2 = bbox
    crop = frame[y1:y2, x1:x2]
    crop = cv2.resize(crop, (32, 64))
    hist = cv2.calcHist([crop], [0, 1, 2], None, [8, 8, 8],
                        [0, 256, 0, 256, 0, 256])
    hist = cv2.normalize(hist, hist).flatten()
    return hist

# %%
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    features_per_frame = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        detections = detect_players(frame)
        features = []
        for detection in detections:
            feat = extract_appearance_feature(frame, detection['bbox'])
            features.append({'bbox': detection['bbox'], 'feature': feat})
        features_per_frame.append(features)
    cap.release()
    return features_per_frame

# %%
def match_players(broadcast_frame_features, tacticam_frame_features):
    if not broadcast_frame_features or not tacticam_frame_features:
        return {}
    broad_feats = np.array([p['feature'] for p in broadcast_frame_features])
    tactic_feats = np.array([p['feature'] for p in tacticam_frame_features])
    dists = cdist(broad_feats, tactic_feats, metric='cosine')
    mapping = {}
    for i, row in enumerate(dists):
        j = np.argmin(row)
        mapping[i] = j
    return mapping

# %%
def main():
    broadcast_features_all_frames = process_video(broadcast_video)
    tacticam_features_all_frames = process_video(tacticam_video)

    all_frames_mapping = []
    for frame_idx, (broadcast_frame_features, tacticam_frame_features) in enumerate(zip(broadcast_features_all_frames, tacticam_features_all_frames)):
        mapping = match_players(broadcast_frame_features, tacticam_frame_features)
        all_frames_mapping.append(mapping)

    print("Player mapping for all frames:")
    for frame_idx, mapping in enumerate(all_frames_mapping):
        print(f"Frame {frame_idx}:")
        if mapping:
            for broadcast_idx, tacticam_idx in mapping.items():
                print(f"  Broadcast player {broadcast_idx} is matched with Tacticam player {tacticam_idx}")
        else:
            print("  No players were detected or matched in this frame.")

# %%
if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 3 players, 66.0ms
# Speed: 4.1ms preprocess, 66.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 65.9ms
# Speed: 3.2ms preprocess, 65.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 53.9ms
# Speed: 2.7ms preprocess, 53.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 37.8ms
# Speed: 2.9ms preprocess, 37.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 38.5ms
# Speed: 3.1ms preprocess, 38.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 38.2ms
# Speed: 3.1ms preprocess, 38.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 14 players, 1 referee, 37.1ms
# Speed: 3.0ms preprocess, 37.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 38.7ms
# Speed: 3.0ms preprocess, 38.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 38.2ms
# Speed: 3.1ms preprocess, 38.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 37.1ms
# Speed: 3.1ms preprocess, 37.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 39.4ms
# Speed: 3.0ms preprocess, 39.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 38.4ms
# Speed: 3.0ms preprocess, 38.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 39.8ms
# Speed: 3.0ms preprocess, 39.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3 referees, 39.0ms
# Speed: 3.1ms preprocess, 39.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 37.7ms
# Speed: 3.0ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 38.4ms
# Speed: 3.0ms preprocess, 38.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 37.2ms
# Speed: 2.9ms preprocess, 37.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2 referees, 39.2ms
# Speed: 3.3ms preprocess, 39.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 37.0ms
# Speed: 3.4ms preprocess, 37.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 38.6ms
# Speed: 3.3ms preprocess, 38.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 36.2ms
# Speed: 3.3ms preprocess, 36.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee,
ms preprocess, 37.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 37.2ms
# Speed: 3.2ms preprocess, 37.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 37.7ms
# Speed: 3.1ms preprocess, 37.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 37.4ms
# Speed: 3.3ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.8ms
# Speed: 3.2ms preprocess, 37.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 3 referees, 37.6ms
# Speed: 2.7ms preprocess, 37.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 37.1ms
# Speed: 4.5ms preprocess, 37.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 23 players, 2 referees, 37.9ms
# Speed: 3.1ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 37.9ms
# Speed: 3.1ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 37.4ms
# Speed: 3.1ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 3 referees, 37.6ms
# Speed: 3.2ms preprocess, 37.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 38.1ms
# Speed: 3.1ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 39.4ms
# Speed: 3.1ms preprocess, 39.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 38.4ms
# Speed: 3.0ms preprocess, 38.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 2 referees, 37.1ms
# Speed: 3.0ms preprocess, 37.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 37.6ms
# Speed: 3.1ms preprocess, 37.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 37.7ms
# Speed: 3.3ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 37.5ms
# Speed: 3.2ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 3 referees, 37.8ms
# Speed: 4.1ms preprocess, 37.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 2 referees, 37.4ms
# Speed: 2.7ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 37.6ms
# Speed: 3.4ms preprocess, 37.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 37.7ms
# Speed: 3.7ms preprocess, 37.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.5ms
# Speed: 2.8ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 38.1ms
# Speed: 3.2ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 37.0ms
# Speed: 2.7ms preprocess, 37.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 38.9ms
# Speed: 3.3ms preprocess, 38.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 37.7ms
# Speed: 3.3ms preprocess, 37.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 38.4ms
# Speed: 3.1ms preprocess, 38.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 38.8ms
# Speed: 3.1ms preprocess, 38.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 37.3ms
# Speed: 3.0ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 37.2ms
# Speed: 3.4ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 38.7ms
# Speed: 3.4ms preprocess, 38.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 37.8ms
# Speed: 3.4ms preprocess, 37.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 36.8ms
# Speed: 3.8ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 37.0ms
# Speed: 3.1ms preprocess, 37.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 39.0ms
# Speed: 3.2ms preprocess, 39.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 38.1ms
# Speed: 3.2ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 37.5ms
# Speed: 3.1ms preprocess, 37.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 37.3ms
# Speed: 4.3ms preprocess, 37.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 37.9ms
# Speed: 3.4ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 38.1ms
# Speed: 2.6ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 38.0ms
# Speed: 3.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 37.4ms
# Speed: 3.1ms preprocess, 37.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 38.5ms
# Speed: 3.2ms preprocess, 38.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 37.6ms
# Speed: 4.3ms preprocess, 37.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 1 referee, 36.7ms
# Speed: 2.9ms preprocess, 36.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 2 referees, 38.3ms
# Speed: 4.3ms preprocess, 38.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 35.7ms
# Speed: 4.4ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 3 referees, 38.2ms
# Speed: 3.0ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 2 referees, 37.9ms
# Speed: 3.0ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 39.3ms
# Speed: 3.0ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 37.3ms
# Speed: 3.1ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 38.6ms
# Speed: 3.1ms preprocess, 38.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 37.3ms
# Speed: 3.0ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 38.5ms
# Speed: 3.0ms preprocess, 38.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 37.5ms
# Speed: 3.6ms preprocess, 37.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 22 players, 2 referees, 38.5ms
# ...
#   Broadcast player 4 is matched with Tacticam player 9
#   Broadcast player 5 is matched with Tacticam player 7
#   Broadcast player 6 is matched with Tacticam player 16
#   Broadcast player 7 is matched with Tacticam player 5
#   Broadcast player 8 is matched with Tacticam player 13
#   Broadcast player 9 is matched with Tacticam player 17
#   Broadcast player 10 is matched with Tacticam player 4
# Frame 99:
#   Broadcast player 0 is matched with Tacticam player 10
#   Broadcast player 1 is matched with Tacticam player 15
#   Broadcast player 2 is matched with Tacticam player 7
#   Broadcast player 3 is matched with Tacticam player 16
#   Broadcast player 4 is matched with Tacticam player 4
#   Broadcast player 5 is matched with Tacticam player 7
#   Broadcast player 6 is matched with Tacticam player 2
#   Broadcast player 7 is matched with Tacticam player 12
#   Broadcast player 8 is matched with Tacticam player 12
#   Broadcast player 9 is matched with Tacticam player 0
# Frame 100:
#   Broadcast player 0 is matched with Tacticam player 13
#   Broadcast player 1 is matched with Tacticam player 16
#   Broadcast player 2 is matched with Tacticam player 6
#   Broadcast player 3 is matched with Tacticam player 13
#   Broadcast player 4 is matched with Tacticam player 1
#   Broadcast player 5 is matched with Tacticam player 7
#   Broadcast player 6 is matched with Tacticam player 7
#   Broadcast player 7 is matched with Tacticam player 13
#   Broadcast player 8 is matched with Tacticam player 16
#   Broadcast player 9 is matched with Tacticam player 3
#   Broadcast player 10 is matched with Tacticam player 8
# Frame 101:
#   Broadcast player 0 is matched with Tacticam player 8
#   Broadcast player 1 is matched with Tacticam player 6
#   Broadcast player 2 is matched with Tacticam player 12
#   Broadcast player 3 is matched with Tacticam player 0
#   Broadcast player 4 is matched with Tacticam player 1
#   Broadcast player 5 is matched with Tacticam player 12
#   Broadcast player 6 is matched with Tacticam player 5
#   Broadcast player 7 is matched with Tacticam player 0
#   Broadcast player 8 is matched with Tacticam player 5
#   Broadcast player 9 is matched with Tacticam player 2
# Frame 102:
#   Broadcast player 0 is matched with Tacticam player 13
#   Broadcast player 1 is matched with Tacticam player 13
#   Broadcast player 2 is matched with Tacticam player 13
#   Broadcast player 3 is matched with Tacticam player 8
#   Broadcast player 4 is matched with Tacticam player 1
#   Broadcast player 5 is matched with Tacticam player 2
#   Broadcast player 6 is matched with Tacticam player 1
#   Broadcast player 7 is matched with Tacticam player 0
#   Broadcast player 8 is matched with Tacticam player 2
#   Broadcast player 9 is matched with Tacticam player 9
#   Broadcast player 10 is matched with Tacticam player 9
# Frame 103:
#   Broadcast player 0 is matched with Tacticam player 2
#   Broadcast player 1 is matched with Tacticam player 6
#   Broadcast player 2 is matched with Tacticam player 16
#   Broadcast player 3 is matched with Tacticam player 4
#   Broadcast player 4 is matched with Tacticam player 6
#   Broadcast player 5 is matched with Tacticam player 0
#   Broadcast player 6 is matched with Tacticam player 0
#   Broadcast player 7 is matched with Tacticam player 10
#   Broadcast player 8 is matched with Tacticam player 10
#   Broadcast player 9 is matched with Tacticam player 11
#   Broadcast player 10 is matched with Tacticam player 10
# Frame 104:
#   Broadcast player 0 is matched with Tacticam player 16
#   Broadcast player 1 is matched with Tacticam player 14
#   Broadcast player 2 is matched with Tacticam player 8
#   Broadcast player 3 is matched with Tacticam player 6
#   Broadcast player 4 is matched with Tacticam player 8
#   Broadcast player 5 is matched with Tacticam player 3
#   Broadcast player 6 is matched with Tacticam player 5
#   Broadcast player 7 is matched with Tacticam player 0
#   Broadcast player 8 is matched with Tacticam player 11
#   Broadcast player 9 is matched with Tacticam player 11
# Frame 105:
#   Broadcast player 0 is matched with Tacticam player 11
#   Broadcast player 1 is matched with Tacticam player 14
#   Broadcast player 2 is matched with Tacticam player 6
#   Broadcast player 3 is matched with Tacticam player 7
#   Broadcast player 4 is matched with Tacticam player 2
#   Broadcast player 5 is matched with Tacticam player 11
#   Broadcast player 6 is matched with Tacticam player 0
#   Broadcast player 7 is matched with Tacticam player 2
#   Broadcast player 8 is matched with Tacticam player 4
#   Broadcast player 9 is matched with Tacticam player 12
#   Broadcast player 10 is matched with Tacticam player 11
# Frame 106:
#   Broadcast player 0 is matched with Tacticam player 6
#   Broadcast player 1 is matched with Tacticam player 10
#   Broadcast player 2 is matched with Tacticam player 11
#   Broadcast player 3 is matched with Tacticam player 3
#   Broadcast player 4 is matched with Tacticam player 12
#   Broadcast player 5 is matched with Tacticam player 5
#   Broadcast player 6 is matched with Tacticam player 0
#   Broadcast player 7 is matched with Tacticam player 2
#   Broadcast player 8 is matched with Tacticam player 10
#   Broadcast player 9 is matched with Tacticam player 14
#   Broadcast player 10 is matched with Tacticam player 14
# Frame 107:
#   Broadcast player 0 is matched with Tacticam player 2
#   Broadcast player 1 is matched with Tacticam player 11
#   Broadcast player 2 is matched with Tacticam player 9
#   Broadcast player 3 is matched with Tacticam player 5
#   Broadcast player 4 is matched with Tacticam player 0
#   Broadcast player 5 is matched with Tacticam player 8
#   Broadcast player 6 is matched with Tacticam player 0
#   Broadcast player 7 is matched with Tacticam player 0
#   Broadcast player 8 is matched with Tacticam player 11
#   Broadcast player 9 is matched with Tacticam player 3
#   Broadcast player 10 is matched with Tacticam player 5
# Frame 108:
#   Broadcast player 0 is matched with Tacticam player 8
#   Broadcast player 1 is matched with Tacticam player 12
#   Broadcast player 2 is matched with Tacticam player 13
#   Broadcast player 3 is matched with Tacticam player 10
#   Broadcast player 4 is matched with Tacticam player 1
#   Broadcast player 5 is matched with Tacticam player 2
#   Broadcast player 6 is matched with Tacticam player 10
#   Broadcast player 7 is matched with Tacticam player 10
#   Broadcast player 8 is matched with Tacticam player 17
#   Broadcast player 9 is matched with Tacticam player 3
# Frame 109:
#   Broadcast player 0 is matched with Tacticam player 3
#   Broadcast player 1 is matched with Tacticam player 17
#   Broadcast player 2 is matched with Tacticam player 3
#   Broadcast player 3 is matched with Tacticam player 7
#   Broadcast player 4 is matched with Tacticam player 17
#   Broadcast player 5 is matched with Tacticam player 12
#   Broadcast player 6 is matched with Tacticam player 3
#   Broadcast player 7 is matched with Tacticam player 10
#   Broadcast player 8 is matched with Tacticam player 7
#   Broadcast player 9 is matched with Tacticam player 16
# Frame 110:
#   Broadcast player 0 is matched with Tacticam player 4
#   Broadcast player 1 is matched with Tacticam player 7
#   Broadcast player 2 is matched with Tacticam player 15
#   Broadcast player 3 is matched with Tacticam player 4
#   Broadcast player 4 is matched with Tacticam player 15
#   Broadcast player 5 is matched with Tacticam player 9
#   Broadcast player 6 is matched with Tacticam player 4
#   Broadcast player 7 is matched with Tacticam player 9
#   Broadcast player 8 is matched with Tacticam player 4
# Frame 111:
#   Broadcast player 0 is matched with Tacticam player 14
#   Broadcast player 1 is matched with Tacticam player 6
#   Broadcast player 2 is matched with Tacticam player 12
#   Broadcast player 3 is matched with Tacticam player 11
#   Broadcast player 4 is matched with Tacticam player 6
#   Broadcast player 5 is matched with Tacticam player 17
#   Broadcast player 6 is matched with Tacticam player 16
#   Broadcast player 7 is matched with Tacticam player 18
#   Broadcast player 8 is matched with Tacticam player 19
# Frame 112:
#   Broadcast player 0 is matched with Tacticam player 17
#   Broadcast player 1 is matched with Tacticam player 0
#   Broadcast player 2 is matched with Tacticam player 12
#   Broadcast player 3 is matched with Tacticam player 6
#   Broadcast player 4 is matched with Tacticam player 6
#   Broadcast player 5 is matched with Tacticam player 5
#   Broadcast player 6 is matched with Tacticam player 17
#   Broadcast player 7 is matched with Tacticam player 15
#   Broadcast player 8 is matched with Tacticam player 12
#   Broadcast player 9 is matched with Tacticam player 5
# Frame 113:
#   Broadcast player 0 is matched with Tacticam player 10
#   Broadcast player 1 is matched with Tacticam player 4
#   Broadcast player 2 is matched with Tacticam player 5
#   Broadcast player 3 is matched with Tacticam player 8
#   Broadcast player 4 is matched with Tacticam player 15
#   Broadcast player 5 is matched with Tacticam player 5
#   Broadcast player 6 is matched with Tacticam player 15
#   Broadcast player 7 is matched with Tacticam player 4
#   Broadcast player 8 is matched with Tacticam player 4
# Frame 114:
#   Broadcast player 0 is matched with Tacticam player 1
#   Broadcast player 1 is matched with Tacticam player 9
#   Broadcast player 2 is matched with Tacticam player 0
#   Broadcast player 3 is matched with Tacticam player 2
#   Broadcast player 4 is matched with Tacticam player 0
#   Broadcast player 5 is matched with Tacticam player 17
#   Broadcast player 6 is matched with Tacticam player 19
#   Broadcast player 7 is matched with Tacticam player 2
#   Broadcast player 8 is matched with Tacticam player 2
#   Broadcast player 9 is matched with Tacticam player 18
# Frame 115:
#   Broadcast player 0 is matched with Tacticam player 6
#   Broadcast player 1 is matched with Tacticam player 1
#   Broadcast player 2 is matched with Tacticam player 7
#   Broadcast player 3 is matched with Tacticam player 1
#   Broadcast player 4 is matched with Tacticam player 17
#   Broadcast player 5 is matched with Tacticam player 8
#   Broadcast player 6 is matched with Tacticam player 18
#   Broadcast player 7 is matched with Tacticam player 2
#   Broadcast player 8 is matched with Tacticam player 10
# Frame 116:
#   Broadcast player 0 is matched with Tacticam player 0
#   Broadcast player 1 is matched with Tacticam player 5
#   Broadcast player 2 is matched with Tacticam player 4
#   Broadcast player 3 is matched with Tacticam player 19
#   Broadcast player 4 is matched with Tacticam player 10
#   Broadcast player 5 is matched with Tacticam player 10
#   Broadcast player 6 is matched with Tacticam player 11
#   Broadcast player 7 is matched with Tacticam player 2
#   Broadcast player 8 is matched with Tacticam player 17
# Frame 117:
#   Broadcast player 0 is matched with Tacticam player 5
#   Broadcast player 1 is matched with Tacticam player 4
#   Broadcast player 2 is matched with Tacticam player 2
#   Broadcast player 3 is matched with Tacticam player 20
#   Broadcast player 4 is matched with Tacticam player 12
#   Broadcast player 5 is matched with Tacticam player 15
#   Broadcast player 6 is matched with Tacticam player 2
#   Broadcast player 7 is matched with Tacticam player 12
#   Broadcast player 8 is matched with Tacticam player 13
# Frame 118:
#   Broadcast player 0 is matched with Tacticam player 13
#   Broadcast player 1 is matched with Tacticam player 6
#   Broadcast player 2 is matched with Tacticam player 12
#   Broadcast player 3 is matched with Tacticam player 3
#   Broadcast player 4 is matched with Tacticam player 15
#   Broadcast player 5 is matched with Tacticam player 3
#   Broadcast player 6 is matched with Tacticam player 12
#   Broadcast player 7 is matched with Tacticam player 13
#   Broadcast player 8 is matched with Tacticam player 3
#   Broadcast player 9 is matched with Tacticam player 13
#   Broadcast player 10 is matched with Tacticam player 13
# Frame 119:
#   Broadcast player 0 is matched with Tacticam player 3
#   Broadcast player 1 is matched with Tacticam player 0
#   Broadcast player 2 is matched with Tacticam player 17
#   Broadcast player 3 is matched with Tacticam player 6
#   Broadcast player 4 is matched with Tacticam player 12
#   Broadcast player 5 is matched with Tacticam player 2
#   Broadcast player 6 is matched with Tacticam player 11
#   Broadcast player 7 is matched with Tacticam player 0
#   Broadcast player 8 is matched with Tacticam player 4
#   Broadcast player 9 is matched with Tacticam player 11
#   Broadcast player 10 is matched with Tacticam player 9
# Frame 120:
#   Broadcast player 0 is matched with Tacticam player 8
#   Broadcast player 1 is matched with Tacticam player 14
#   Broadcast player 2 is matched with Tacticam player 19
#   Broadcast player 3 is matched with Tacticam player 11
#   Broadcast player 4 is matched with Tacticam player 19
#   Broadcast player 5 is matched with Tacticam player 15
#   Broadcast player 6 is matched with Tacticam player 10
#   Broadcast player 7 is matched with Tacticam player 1
#   Broadcast player 8 is matched with Tacticam player 7
# Frame 121:
#   Broadcast player 0 is matched with Tacticam player 5
#   Broadcast player 1 is matched with Tacticam player 14
#   Broadcast player 2 is matched with Tacticam player 20
#   Broadcast player 3 is matched with Tacticam player 8
#   Broadcast player 4 is matched with Tacticam player 16
#   Broadcast player 5 is matched with Tacticam player 3
#   Broadcast player 6 is matched with Tacticam player 20
#   Broadcast player 7 is matched with Tacticam player 5
#   Broadcast player 8 is matched with Tacticam player 13
#   Broadcast player 9 is matched with Tacticam player 8
# Frame 122:
#   Broadcast player 0 is matched with Tacticam player 13
#   Broadcast player 1 is matched with Tacticam player 13
#   Broadcast player 2 is matched with Tacticam player 13
#   Broadcast player 3 is matched with Tacticam player 8
#   Broadcast player 4 is matched with Tacticam player 12
#   Broadcast player 5 is matched with Tacticam player 10
#   Broadcast player 6 is matched with Tacticam player 7
#   Broadcast player 7 is matched with Tacticam player 20
#   Broadcast player 8 is matched with Tacticam player 5
# Frame 123:
#   Broadcast player 0 is matched with Tacticam player 4
#   Broadcast player 1 is matched with Tacticam player 3
#   Broadcast player 2 is matched with Tacticam player 11
#   Broadcast player 3 is matched with Tacticam player 10
#   Broadcast player 4 is matched with Tacticam player 4
#   Broadcast player 5 is matched with Tacticam player 12
#   Broadcast player 6 is matched with Tacticam player 9
#   Broadcast player 7 is matched with Tacticam player 5
#   Broadcast player 8 is matched with Tacticam player 21
#   Broadcast player 9 is matched with Tacticam player 5
# Frame 124:
#   Broadcast player 0 is matched with Tacticam player 8
#   Broadcast player 1 is matched with Tacticam player 4
#   Broadcast player 2 is matched with Tacticam player 0
#   Broadcast player 3 is matched with Tacticam player 10
#   Broadcast player 4 is matched with Tacticam player 17
#   Broadcast player 5 is matched with Tacticam player 8
#   Broadcast player 6 is matched with Tacticam player 3
#   Broadcast player 7 is matched with Tacticam player 7
#   Broadcast player 8 is matched with Tacticam player 20
# Frame 125:
#   Broadcast player 0 is matched with Tacticam player 17
#   Broadcast player 1 is matched with Tacticam player 0
#   Broadcast player 2 is matched with Tacticam player 13
#   Broadcast player 3 is matched with Tacticam player 13
#   Broadcast player 4 is matched with Tacticam player 6
#   Broadcast player 5 is matched with Tacticam player 12
#   Broadcast player 6 is matched with Tacticam player 17
#   Broadcast player 7 is matched with Tacticam player 3
#   Broadcast player 8 is matched with Tacticam player 19
#   Broadcast player 9 is matched with Tacticam player 3
# Frame 126:
#   No players were detected or matched in this frame.
# Frame 127:
#   No players were detected or matched in this frame.
# Frame 128:
#   No players were detected or matched in this frame.
# Frame 129:
#   No players were detected or matched in this frame.
# Frame 130:
#   No players were detected or matched in this frame.
# Frame 131:
#   No players were detected or matched in this frame.
